# %%
import pandas as pd
import yfinance as yf
from datetime import datetime

# %%
import numpy
numpy.version.version
# Out:
# '2.2.6'

# %%
yf.version.version
# Out:
# '0.2.61'

# %%
from yahoofinancials import YahooFinancials

# %%
# let's get the data for Apple Inc. (AAPL) from Yahoo Finance
# using yfinance library
# Note: The yfinance library is a popular library for downloading
# financial data from Yahoo Finance. It is a Python wrapper
# around the Yahoo Finance API and provides a simple interface
# to access financial data such as stock prices, historical data,
# and company information.
aapl_df = yf.download('AAPL', 
                      start='2025-01-01', 
                      end='2025-05-20', 
                      progress=False,
)
print(aapl_df.head())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-01-02  243.263199  248.500565  241.238085  248.330961  55740700
# 2025-01-03  242.774368  243.592387  241.307905  242.774368  40244100
# 2025-01-06  244.410416  246.734810  242.614744  243.722074  45045600
# 2025-01-07  241.627136  244.959095  240.769205  242.395272  40856000
# 2025-01-08  242.115936  243.123515  239.472320  241.337815  37628900

# %%
print(aapl_df.tail())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-05-13  212.929993  213.399994  209.000000  210.429993  51909300
# 2025-05-14  212.330002  213.940002  210.580002  212.429993  49325800
# 2025-05-15  211.449997  212.960007  209.539993  210.949997  45029500
# 2025-05-16  211.259995  212.570007  209.770004  212.360001  54737900
# 2025-05-19  208.779999  209.479996  204.259995  207.910004  45310800

# %%
aapl_df = yf.download('AAPL')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import matplotlib

# %%
ticker = yf.Ticker('AAPL')
aapl_df = ticker.history(period="10y")
aapl_df['Close'].plot(title="APPLE's stock price")
# Out:
# <Axes: title={'center': "APPLE's stock price"}, xlabel='Date'>

# %%
tickerg = yf.Ticker('GOOG')
aapl_df = tickerg.history(period="40y")
aapl_df['Close'].plot(title="Google's stock price")
# Out:
# <Axes: title={'center': "Google's stock price"}, xlabel='Date'>

# %%
dir(ticker)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_data',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_expirations',
#  '_fast_info',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fundamentals',
#  '_funds_data',
#  '_get_ticker_tz',
#  '_holders',
#  '_isin',
#  '_lazy_load_price_history',
#  '_message_handler',
#  '_news',
#  '_options2df',
#  '_price_history',
#  '_quote',
#  '_shares',
#  '_tz',
#  '_underlying',
#  'actions',
#  'analyst_price_targets',
#  'balance_sheet',
#  'balancesheet',
#  'basic_info',
#  'calendar',
#  'capital_gains',
# ...

# %%
for k,v in ticker.info.items():
    print (k, '\t', v, '\n')
# Out:
# address1 	 One Apple Park Way
#
# city 	 Cupertino
#
# state 	 CA
#
# zip 	 95014
#
# country 	 United States
#
# phone 	 (408) 996-1010
#
# website 	 https://www.apple.com
#
# industry 	 Consumer Electronics
#
# industryKey 	 consumer-electronics
#
# industryDisp 	 Consumer Electronics
#
# sector 	 Technology
#
# sectorKey 	 technology
#
# sectorDisp 	 Technology
#
# ...

# %%
for k,v in tickerg.info.items():
    print (k, '\t', v, '\n')
# Out:
# address1 	 1600 Amphitheatre Parkway
#
# city 	 Mountain View
#
# state 	 CA
#
# zip 	 94043
#
# country 	 United States
#
# phone 	 650-253-0000
#
# website 	 https://abc.xyz
#
# industry 	 Internet Content & Information
#
# industryKey 	 internet-content-information
#
# industryDisp 	 Internet Content & Information
#
# sector 	 Communication Services
#
# sectorKey 	 communication-services
#
# sectorDisp 	 Communication Services
#
# ...

# %%
ticker.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          7   20    16     2           1
# 1    -1m          7   23    16     1           1
# 2    -2m          7   21    14     2           1
# 3    -3m          7   21    13     2           2

# %%
ticker.sustainability
# Out:
#                                                                            esgScores
# maxAge                                                                         86400
# totalEsg                                                                       18.99
# environmentScore                                                                2.44
# socialScore                                                                     7.98
# governanceScore                                                                 8.58
# ratingYear                                                                      2025
# ratingMonth                                                                        5
# highestControversy                                                               3.0
# peerCount                                                                        231
# esgPerformance                                                              LAG_PERF
# ...

# %%
print(ticker.actions)
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0
# ...                              ...           ...
# 2024-05-10 00:00:00-04:00   0.250000           0.0
# 2024-08-12 00:00:00-04:00   0.250000           0.0
# 2024-11-08 00:00:00-05:00   0.250000           0.0
# 2025-02-10 00:00:00-05:00   0.250000           0.0
# 2025-05-12 00:00:00-04:00   0.260000           0.0
#
# [92 rows x 2 columns]

# %%
ticker.info['dividendYield']
ticker.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...
